# %%
import random

# %%
lenght = int(input("Enter the lenght of the password: "))
letters = input("Enter your name : ")
digits =  input('isdigit')
all_characters = letters + digits 
password = ''.join(random.choice(all_characters) for i in range(lenght) )
print("Your random password is : ", password)
# Out:
# Enter the lenght of the password:  8
# Enter your name :  vashu
# isdigit 2003
# Your random password is :  h3s00sa3
